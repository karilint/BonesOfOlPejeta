# %%
import pandas as pd
from pathlib import Path

df_transects = pd.read_pickle("../data/pkl/df_transects.pkl")
df_transects.head()
# Out:
#       UID Name          start_time           turn_time            end_time  \
# 0  271687   48 2011-07-08 16:09:19 2011-07-08 17:38:38 2011-07-08 17:53:34
# 1  274498   49 2011-07-10 14:59:39 2011-07-10 15:21:22 2011-07-12 12:40:34
# 2  277434   50 2011-07-12 15:59:36 2011-07-13 15:05:27 2011-07-13 15:56:27
# 3  278888   51 2011-07-13 16:09:31 2011-07-15 12:33:06 2011-07-15 12:47:30
# 4  285685   52 2011-07-18 09:28:36 2011-07-18 10:31:19 2011-07-18 11:15:07
#
#    lat_from  long_from  lat_turn  long_turn    lat_to  ...  \
# 0  0.019397  36.944255  0.019248  36.936132  0.019248  ...
# 1  0.021680  36.941568  0.021160  36.935927  0.021160  ...
# 2  0.022625  36.930758  0.022605  36.939808  0.022625  ...
# 3  0.023828  36.930668  0.023388  36.938127  0.023388  ...
# 4  0.087638  36.828862  0.087870  36.837802  0.087870  ...
#
#                  Post: Notes on Transect End  Pre: Ecomorphology habitat  \
# 0  ended at 900m, transect end near bushland              open/tree-less
# 1                                        NaN              open/tree-less
# 2                                        NaN              open/tree-less
# 3                                        NaN              open/tree-less
# 4                    3 patches of hyena poop                       O;WBG
#
#    Pre: New Transect?                                  Pre: Notes  \
# 0                 Yes  start just south of road off grants plains
# 1                 Yes                                         NaN
# 2                 Yes                                         NaN
# 3                 Yes                                         NaN
# 4                 Yes                                         NaN
#
#                         Pre: Notes on Transect Start  Pre: OPC Vegetation  \
# 0                                                NaN                  NaN
# 1                                a bit north of road                  NaN
# 2                                       heading east                  NaN
# 3                                                                     NaN
# 4  transitional between opn and wooded bushed gra...                  NaN
#
#   Pre: On old reserve? Pre: Reserve vegetation Pre: Transect physical habitat  \
# 0                  Yes                     NaN                   grass closed
# 1                  Yes                     NaN                   grass closed
# 2                  Yes                     NaN                   grass closed
# 3                  Yes                     NaN                   grass closed
# 4                   No                     NaN                   grass closed
#
#   Pre: Transect vegetation
# 0                    grass
# 1                    grass
# 2                    grass
# 3                    grass
# 4                    grass
#
# [5 rows x 26 columns]

# %%
df_occurrences_with_taxon = pd.read_pickle("../data/pkl/df_occurrences_with_taxon.pkl")
df_occurrences_with_taxon.head(10)
# Out:
#    ID  TransectUID  OccurrenceNumber  RecordingStartTime    RecordingEndTime  \
# 0   1      4354089                 1 2003-02-17 09:12:35 2003-02-17 17:14:57
# 1   2      4354089                 2 2003-02-17 09:17:26 2003-02-17 17:20:34
# 2   3      4354089                 3 2003-02-17 09:55:37 2003-02-17 10:05:08
# 3   4      4354089                 4 2003-02-17 10:14:26 2003-02-17 10:15:34
# 4   5      4354089                 5 2003-02-17 10:30:03 2003-02-17 16:08:58
# 5   6      4354089                 6 2003-02-17 10:33:39 2003-02-17 11:17:28
# 6   7      4354089                 7 2003-02-17 11:33:08 2003-02-17 16:34:29
# 7   8      4354089                 8 2003-02-17 11:41:05 2003-02-17 11:43:31
# 8   9      4354089                 9 2003-02-17 11:45:56 2003-02-17 11:47:09
# 9  10      4354089                10 2003-02-17 11:54:30 2003-03-17 20:26:22
#
#         Lat       Long  Note      State Post: Age  ... Pre: Notes - fresh  \
# 0  0.042495  36.970267  None  Completed       NaN  ...
# 1  0.042522  36.966980  None  Completed       NaN  ...
# 2  0.042432  36.966908  None  Completed       NaN  ...
# 3  0.042495  36.966773  None  Completed       NaN  ...
# 4  0.042549  36.966055  None  Completed       NaN  ...
# 5  0.042594  36.963046  None  Completed       NaN  ...
# 6  0.042558  36.962040  None  Completed       NaN  ...
# 7  0.042594  36.962004  None  Completed       NaN  ...
# 8  0.042608  36.961968  None  Completed       NaN  ...
# 9  0.042639  36.961986  None  Completed       NaN  ...
#
#   Pre: Sex Pre: Size class        Pre: Taxon year_died_latest  \
# 0  Unknown            3b-4   Bovidae (large)             1999
# 1  Unknown               4             eland             1996
# 2  Unknown               4             zebra             2002
# 3  Unknown     0 - unknown    Mammalia indet             1996
# 4  Unknown               3  Bovidae (medium)             2001
# 5  Unknown               4             zebra             2002
# 6  Unknown            3b-4    Mammalia indet             1999
# 7  Unknown               4             zebra             1999
# 8  Unknown               4             zebra             1996
# 9  Unknown               4             zebra             2001
#
#   year_died_earliest       Taxon Label      UID  \
# 0               1995   Bovidae (large)  4354089
# 1               1983             eland  4354089
# 2               2000             zebra  4354089
# 3               1983    Mammalia indet  4354089
# 4               1998  Bovidae (medium)  4354089
# 5               2000             zebra  4354089
# 6               1995             zebra  4354089
# 7               1995             zebra  4354089
# 8               1983             zebra  4354089
# 9               1998             zebra  4354089
#
#   Pre: Transect physical habitat Pre: On old reserve?
# 0                   grass closed                  Yes
# 1                   grass closed                  Yes
# 2                   grass closed                  Yes
# 3                   grass closed                  Yes
# 4                   grass closed                  Yes
# 5                   grass closed                  Yes
# 6                   grass closed                  Yes
# 7                   grass closed                  Yes
# 8                   grass closed                  Yes
# 9                   grass closed                  Yes
#
# [10 rows x 39 columns]

# %%
df_instances = pd.read_pickle("../data/pkl/df_instances.pkl")
df_instances.head()
# Out:
#                                     UID  OccurrenceID  \
# 0  C3CD24C5-09B7-42DB-A5BE-82C862FCEE6A           265
# 1  28FC916B-F859-444C-A3B6-24F1040AB291           265
# 2  FF2ABC54-0172-4A03-81FE-72BAB7CE4C41           265
# 3  43E88323-2CA0-4A29-8552-480BB96E4ACB           265
# 4  24D9C6B4-FADC-4706-B09B-80EAD9F15D57           265
#
#                      TemplateWorkflowID  InstanceNumber CompletedBy     ID  \
# 0  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               1      Briana  265.0
# 1  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               2      Briana  265.0
# 2  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               3      Briana  265.0
# 3  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               4      Briana  265.0
# 4  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               5      Briana  265.0
#
#    TransectUID  OccurrenceNumber  RecordingStartTime    RecordingEndTime  ...  \
# 0     271687.0               1.0 2011-07-08 16:24:01 2011-07-08 16:30:47  ...
# 1     271687.0               1.0 2011-07-08 16:24:01 2011-07-08 16:30:47  ...
# 2     271687.0               1.0 2011-07-08 16:24:01 2011-07-08 16:30:47  ...
# 3     271687.0               1.0 2011-07-08 16:24:01 2011-07-08 16:30:47  ...
# 4     271687.0               1.0 2011-07-08 16:24:01 2011-07-08 16:30:47  ...
#
#     Pre: Local Context  Pre: Notes - fresh Pre: Sex Pre: Size class  \
# 0  in tall grass patch     dried skin bits  Unknown              3b
# 1  in tall grass patch     dried skin bits  Unknown              3b
# 2  in tall grass patch     dried skin bits  Unknown              3b
# 3  in tall grass patch     dried skin bits  Unknown              3b
# 4  in tall grass patch     dried skin bits  Unknown              3b
#
#   Pre: Taxon  Name               DateAdded AddedBy year_died_latest  \
# 0      zebra  Bone 2019-10-15 00:42:13.370    nick             2009
# 1      zebra  Bone 2019-10-15 00:42:13.370    nick             2010
# 2      zebra  Bone 2019-10-15 00:42:13.370    nick             2010
# 3      zebra  Bone 2019-10-15 00:42:13.370    nick             2010
# 4      zebra  Bone 2019-10-15 00:42:13.370    nick             2010
#
#   year_died_earliest
# 0               2006
# 1               2008
# 2               2008
# 3               2008
# 4               2008
#
# [5 rows x 44 columns]

# %%
df_briana_with_responses = pd.read_pickle("../data/pkl/df_briana_with_responses.pkl")
df_briana_with_responses.head()
# Out:
#                                     UID  OccurrenceID  \
# 0  B5E69EAE-E4FF-1B3E-F38B-0EC66DAC8774             1
# 1  789F0CCC-7D1C-816F-F29C-B4E0BB3B82AB             2
# 2  316C833E-D57B-C57D-6EB9-0F6447D46963             3
# 3  17F84367-F24B-B574-F9CC-0CFF4F414BC0             3
# 4  0FF21BFC-21B9-7915-45B2-5D82706B82B5             3
#
#                      TemplateWorkflowID  InstanceNumber CompletedBy  \
# 0  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               1      Briana
# 1  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               1      Briana
# 2  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               1      Briana
# 3  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               2      Briana
# 4  AED98AE9-DD15-4449-B60D-C9F27A02F2EE               3      Briana
#
#   Are there ecomorphable elements? Articulated?  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                                    Bone notes Buried - Notes Buried?  ...  \
# 0                                                                 No  ...
# 1  damage but not sure if caused by carnivore                     No  ...
# 2                                                                 No  ...
# 3                                                                 No  ...
# 4                                                                 No  ...
#
#   UPM4 lo UPM4 wc UPM4 wo Upper or lower? Vertebra Portion Weathering class  \
# 0     NaN     NaN     NaN             NaN                                 3
# 1     NaN     NaN     NaN             NaN                                 4
# 2     NaN     NaN     NaN             NaN                                 1
# 3     NaN     NaN     NaN             NaN                                 1
# 4     NaN     NaN     NaN             NaN                                 1
#
#   What element is this? upper or lower? year_died_latest year_died_earliest
# 0             calcaneus             NaN             1999               1995
# 1         hemi-mandible             NaN             1996               1983
# 2         hemi-mandible             NaN             2002               2000
# 3         hemi-mandible             NaN             2002               2000
# 4         hemi-mandible             NaN             2002               2000
#
# [5 rows x 393 columns]

# %%
df_fire_with_responses = pd.read_pickle("../data/pkl/df_fire_with_responses.pkl")
df_fire_with_responses.head()
# Out:
#                                     UID  OccurrenceID  \
# 0  A4802CC8-E5E0-439E-B6EC-38F3F46836D0           269
# 1  B1AE1CD6-16E1-4C69-80B4-1DC02EBA1F0D           272
# 2  29428771-CDA7-48BA-87ED-6B52BDE512FB           273
# 3  36390049-5D37-44EB-AEFE-63651658463E           273
# 4  EC8379E0-1868-4CD7-9130-89E546E91755           273
#
#                      TemplateWorkflowID  InstanceNumber CompletedBy  \
# 0  DE54448B-7AAD-4E55-B364-795A6F2888A7               3        Fire
# 1  651BD177-976C-4D35-8BE9-8DFC3736BA9F               1        Fire
# 2  651BD177-976C-4D35-8BE9-8DFC3736BA9F               1        Fire
# 3  651BD177-976C-4D35-8BE9-8DFC3736BA9F               2        Fire
# 4  114A785B-804D-4AEB-892B-D6116DF31303               3        Fire
#
#   Are there ecomorphable elements? Articulated? Bone notes Buried - Notes  \
# 0                              NaN          NaN        NaN            NaN
# 1                              NaN          NaN        NaN            NaN
# 2                              NaN          NaN        NaN            NaN
# 3                              NaN          NaN        NaN            NaN
# 4                              NaN          NaN        NaN            NaN
#
#   Buried?  ... UPM lo UPM4 lc UPM4 lo UPM4 wc UPM4 wo Upper or lower?  \
# 0     NaN  ...    NaN     NaN     NaN     NaN     NaN             NaN
# 1     NaN  ...    NaN     NaN     NaN     NaN     NaN             NaN
# 2     NaN  ...    NaN     NaN     NaN     NaN     NaN             NaN
# 3     NaN  ...    NaN     NaN     NaN     NaN     NaN             NaN
# 4     NaN  ...    NaN     NaN     NaN     NaN     NaN             NaN
#
#   Vertebra Portion Weathering class What element is this? upper or lower?
# 0              NaN              NaN                   NaN             NaN
# 1              NaN              NaN                   NaN             NaN
# 2              NaN              NaN                   NaN             NaN
# 3              NaN              NaN                   NaN             NaN
# 4              NaN              NaN                   NaN             NaN
#
# [5 rows x 391 columns]

# %%
# Filter transects excluding year 2008 and most 2024 transects (keep 2024 'shrubs closed')
# Filter transects to only those marked as "on old reserve"
df_transects['Year'] = pd.to_datetime(df_transects['start_time']).dt.year
mask_not_2008 = df_transects['Year'] != 2008
mask_keep_2024 = ~((df_transects['Year'] == 2024) & (df_transects['Pre: Transect physical habitat'] != 'shrubs closed'))
df_filtered_transects = df_transects[mask_not_2008 & mask_keep_2024].copy()

df_old_reserve_transects = df_filtered_transects[df_filtered_transects["Pre: On old reserve?"] == "Yes"].copy()
valid_transect_uids = df_old_reserve_transects['UID']

# Count by 'Pre: Transect physical habitat'
counts = df_old_reserve_transects["Pre: Transect physical habitat"].value_counts()

# Convert to a single-row DataFrame with habitat types as columns
summary_table = pd.DataFrame([counts])
summary_table.index = ['# of transects']

# Step 2: Join df_occurrences to get the habitat info
df_occ_with_habitat = df_occurrences_with_taxon.merge(
    df_old_reserve_transects[['UID', 'Pre: Transect physical habitat']],
    how='inner',
    left_on='TransectUID',
    right_on='UID'
)

# Step 3: Group and count occurrences (MNI)
mni_counts = df_occ_with_habitat['Pre: Transect physical habitat_x'].value_counts()

# Step 4: Add MNI row to the summary table
summary_table.loc['MNI (n)'] = summary_table.columns.map(mni_counts).fillna(0).astype(int)

# By Taxa
# Filter transects to 'old reserve' only
#df_occ_with_habitat['Taxon Label'] = df_occ_with_habitat['Post: Taxon Guess?'].fillna(
#    df_occ_with_habitat['Pre: Taxon']
#)

taxon_summary = df_occ_with_habitat.pivot_table(
    index='Taxon Label',
    columns='Pre: Transect physical habitat_x',
    values='ID',
    aggfunc='count',
    fill_value=0
)

# Align and append to summary_table
taxon_summary = taxon_summary.reindex(columns=summary_table.columns, fill_value=0)
summary_table = pd.concat([summary_table, taxon_summary])

# %%
# km2 covered
# Multiply each transect's distance by 0.05 to estimate area
df_old_reserve_transects['area_km2'] = df_old_reserve_transects['distance_km'] * 0.05

# Sum area per habitat type
area_by_habitat = df_old_reserve_transects.groupby("Pre: Transect physical habitat")["area_km2"].sum()

# Align with column order of summary_table
#area_row = summary_table.columns.map(area_by_habitat).fillna(0).round(2)
area_row = pd.Series(summary_table.columns.map(area_by_habitat)).fillna(0).astype(float).round(2)
# Now assign the row (note: index should match summary_table.columns)
area_row.index = summary_table.columns

# Add to summary_table
summary_table.loc['km2 covered'] = area_row
summary_table
# Out:
# Pre: Transect physical habitat  grass closed  shrubs open  shrubs closed  \
# # of transects                         19.00         18.0          18.00
# MNI (n)                               243.00        213.0          96.00
# Aves (medium)                           1.00          0.0           1.00
# Aves (small)                            0.00          1.0           1.00
# Bovidae (large)                         6.00          7.0           7.00
# Bovidae (medium)                       18.00          9.0           3.00
# Bovidae (small)                         9.00          6.0           6.00
# Grant's gazelle                         6.00          1.0           1.00
# Mammalia indet                         44.00         70.0          31.00
# Rhinocerotidae                          0.00          1.0           0.00
# Thompson's gazelle                     19.00          4.0           0.00
# black rhinoceros                        1.00          0.0           0.00
# buffalo                                 4.00         14.0           5.00
# cow (domestic)                          4.00          1.0           0.00
# eland                                   2.00          2.0           7.00
# elephant                                0.00          0.0           0.00
# giraffe                                12.00          8.0           6.00
# hare                                    1.00          0.0           0.00
# hartebeest                              4.00          2.0           0.00
# impala                                  3.00         10.0           1.00
# reedbuck                                0.00          0.0           0.00
# spotted hyaena                          0.00          1.0           0.00
# ungulate                                0.00          0.0           3.00
# warthog                                23.00         21.0           2.00
# waterbuck                               3.00          5.0           5.00
# zebra                                  83.00         50.0          17.00
# km2 covered                             0.97          0.9           0.77
#
# Pre: Transect physical habitat  trees closed
# # of transects                         10.00
# MNI (n)                                28.00
# Aves (medium)                           0.00
# Aves (small)                            0.00
# Bovidae (large)                         0.00
# Bovidae (medium)                        1.00
# Bovidae (small)                         1.00
# Grant's gazelle                         0.00
# Mammalia indet                          4.00
# Rhinocerotidae                          0.00
# Thompson's gazelle                      0.00
# black rhinoceros                        0.00
# buffalo                                 0.00
# cow (domestic)                          0.00
# eland                                   0.00
# elephant                                2.00
# giraffe                                 3.00
# hare                                    1.00
# hartebeest                              0.00
# impala                                  4.00
# reedbuck                                1.00
# spotted hyaena                          0.00
# ungulate                                0.00
# warthog                                 1.00
# waterbuck                               4.00
# zebra                                   6.00
# km2 covered                             0.54

# %%
# Calculate MNI per km² (avoid division by zero just in case)
mni_row = summary_table.loc['MNI (n)']
area_row = summary_table.loc['km2 covered']

mni_per_km2 = (mni_row / area_row.replace(0, pd.NA)).round().fillna(0)
summary_table.loc['MNI/km2'] = pd.Series(mni_per_km2, index=summary_table.columns)
summary_table.loc['MNI/km2'].apply(type)
# Out:
# Pre: Transect physical habitat
# grass closed     <class 'float'>
# shrubs open      <class 'float'>
# shrubs closed    <class 'float'>
# trees closed     <class 'float'>
# Name: MNI/km2, dtype: object

# %%
# NISP (# of bones)
# Merge df_instances with df_occurrences (to get TransectUID)
df_instances_with_occ = df_instances.merge(
    df_occurrences_with_taxon[['ID', 'TransectUID']],
    how='inner',
    left_on='OccurrenceID',
    right_on='ID',
    suffixes=('', '_occ')
)

# Merge with df_transects to get the habitat
df_instances_full = df_instances_with_occ.merge(
    df_old_reserve_transects[['UID', 'Pre: Transect physical habitat', 'Pre: On old reserve?']],
    how='inner',
    left_on='TransectUID',
    right_on='UID',
    suffixes=('', '_transect')
)

# Filter to "old reserve" transects (if needed)

df_instances_old_reserve = df_instances_full[df_instances_full["Pre: On old reserve?"] == "Yes"].copy()

# Count instances per habitat (aka NISP)
nisp_counts = df_instances_old_reserve['Pre: Transect physical habitat'].value_counts()
nisp_row = summary_table.columns.map(nisp_counts).fillna(0).astype(int)
summary_table.loc['NISP (# of bones)'] = nisp_row

# %%
# NISP/km2
# Get existing rows from the summary table
nisp_row = summary_table.loc['NISP (# of bones)']
area_row = summary_table.loc['km2 covered']

# Calculate NISP per km², round, and convert to int
nisp_per_km2 = (nisp_row / area_row.replace(0, pd.NA)).round().fillna(0).astype(int)

# Add to the summary table
summary_table.loc['NISP/km2'] = pd.Series(nisp_per_km2, index=summary_table.columns)

# %%
# Weathering class percentages
df_briana_with_occ = df_briana_with_responses.merge(
    df_occurrences_with_taxon[['ID', 'TransectUID']],
    how='left',
    left_on='OccurrenceID',
    right_on='ID',
    suffixes=('', '_occ')
)

df_briana_with_occ_transect = df_briana_with_occ.merge(
    df_old_reserve_transects[['UID', 'Pre: Transect physical habitat', 'Pre: On old reserve?']],
    how='inner',
    left_on='TransectUID',
    right_on='UID',
    suffixes=('', '_transect')
)

# Only old reserve
df_briana_old_reserve = df_briana_with_occ_transect[
    df_briana_with_occ_transect['Pre: On old reserve?'] == 'Yes'
].copy()

weathering_counts = df_briana_old_reserve.pivot_table(
    index='Weathering class',
    columns='Pre: Transect physical habitat',
    values='UID',
    aggfunc='count',
    fill_value=0
)

weathering_percent = weathering_counts.div(weathering_counts.sum(axis=0), axis=1) * 100
weathering_percent = weathering_percent.round(1)

# Reindex to match summary table column order
weathering_percent = weathering_percent.reindex(columns=summary_table.columns, fill_value=0)

# Add rows to summary table
for label, row in weathering_percent.iterrows():
    summary_table.loc[f'Weathering class {label} (%)'] = row

# %%
# Count total instances per habitat (denominator)
nisp_total = df_briana_old_reserve['Pre: Transect physical habitat'].value_counts()

# Count buried instances per habitat (numerator)
buried = df_briana_old_reserve[df_briana_old_reserve['Buried?'] == 'Yes']
buried_counts = buried['Pre: Transect physical habitat'].value_counts()

# Calculate percentage
buried_percent = (buried_counts / nisp_total * 100).round(1)

# Align with summary table columns
buried_row = summary_table.columns.map(buried_percent).fillna(0)

# Add row to summary table
summary_table.loc['% buried bones'] = buried_row

# %%
# % bones with any carnivore damage

# Instances with any carnivore damage
# Count where there is *any* non-null damage level
# Count only valid carnivore damage levels (as strings just in case)
valid_damage_levels = {'1', '2', '3', '4'}

has_valid_carn_damage = df_briana_old_reserve[
    df_briana_old_reserve['Carn Damage 1 Level'].astype(str).isin(valid_damage_levels)
]

carn_counts = has_valid_carn_damage['Pre: Transect physical habitat'].value_counts()

# Calculate % per habitat
carn_percent = (carn_counts / nisp_total * 100).round(1)

# Align with summary_table columns
carn_row = summary_table.columns.map(carn_percent).fillna(0)

summary_table.loc['% bones with any carnivore damage'] = carn_row

# %%
# Export summary_table to formatted Excel table
output_path = Path('../data/export/excel/table_summary_by_biomes.xlsx')
output_path.parent.mkdir(parents=True, exist_ok=True)
with pd.ExcelWriter(output_path, engine='xlsxwriter') as writer:
    summary_table.to_excel(writer, index=True, sheet_name='Summary')
    workbook  = writer.book
    worksheet = writer.sheets['Summary']
    max_row, max_col = summary_table.shape
    worksheet.add_table(0, 0, max_row, max_col - 1, {'columns': [{'header': col} for col in summary_table.columns]})
    fmt = workbook.add_format({'num_format': '0.00'})
    worksheet.set_column('C:C', None, fmt)
    worksheet.set_column('E:E', None, fmt)

# %%
# View the result
summary_table
# Out:
# Pre: Transect physical habitat     grass closed  shrubs open  shrubs closed  \
# # of transects                            19.00         18.0          18.00
# MNI (n)                                  243.00        213.0          96.00
# Aves (medium)                              1.00          0.0           1.00
# Aves (small)                               0.00          1.0           1.00
# Bovidae (large)                            6.00          7.0           7.00
# Bovidae (medium)                          18.00          9.0           3.00
# Bovidae (small)                            9.00          6.0           6.00
# Grant's gazelle                            6.00          1.0           1.00
# Mammalia indet                            44.00         70.0          31.00
# Rhinocerotidae                             0.00          1.0           0.00
# Thompson's gazelle                        19.00          4.0           0.00
# black rhinoceros                           1.00          0.0           0.00
# buffalo                                    4.00         14.0           5.00
# cow (domestic)                             4.00          1.0           0.00
# eland                                      2.00          2.0           7.00
# elephant                                   0.00          0.0           0.00
# giraffe                                   12.00          8.0           6.00
# hare                                       1.00          0.0           0.00
# hartebeest                                 4.00          2.0           0.00
# impala                                     3.00         10.0           1.00
# reedbuck                                   0.00          0.0           0.00
# spotted hyaena                             0.00          1.0           0.00
# ungulate                                   0.00          0.0           3.00
# warthog                                   23.00         21.0           2.00
# waterbuck                                  3.00          5.0           5.00
# zebra                                     83.00         50.0          17.00
# km2 covered                                0.97          0.9           0.77
# MNI/km2                                  251.00        237.0         125.00
# NISP (# of bones)                       1300.00       1136.0         719.00
# NISP/km2                                1340.00       1262.0         934.00
# Weathering class 0 (%)                    35.80         12.4          17.40
# Weathering class 0-1 (%)                   6.60          0.0           3.50
# Weathering class 1 (%)                    20.30         20.3          13.40
# Weathering class 1-2 (%)                   2.00          0.0           1.90
# Weathering class 2 (%)                     9.10         13.0           9.00
# Weathering class 2-3 (%)                   0.70          0.4           1.10
# Weathering class 3 (%)                    14.20         27.4          12.40
# Weathering class 3-4 (%)                   0.60          0.6           0.20
# Weathering class 4 (%)                     6.80         14.8          33.40
# Weathering class 4-5 (%)                   0.50          0.5           0.30
# Weathering class 5 (%)                     3.30         10.5           6.90
# Weathering class 6 (%)                     0.00          0.0           0.30
# % buried bones                             3.80          7.7          13.90
# % bones with any carnivore damage         21.00          6.0           5.10
#
# Pre: Transect physical habitat     trees closed
# # of transects                            10.00
# MNI (n)                                   28.00
# Aves (medium)                              0.00
# Aves (small)                               0.00
# Bovidae (large)                            0.00
# Bovidae (medium)                           1.00
# Bovidae (small)                            1.00
# Grant's gazelle                            0.00
# Mammalia indet                             4.00
# Rhinocerotidae                             0.00
# Thompson's gazelle                         0.00
# black rhinoceros                           0.00
# buffalo                                    0.00
# cow (domestic)                             0.00
# eland                                      0.00
# elephant                                   2.00
# giraffe                                    3.00
# hare                                       1.00
# hartebeest                                 0.00
# impala                                     4.00
# reedbuck                                   1.00
# spotted hyaena                             0.00
# ungulate                                   0.00
# warthog                                    1.00
# waterbuck                                  4.00
# zebra                                      6.00
# km2 covered                                0.54
# MNI/km2                                   52.00
# NISP (# of bones)                        129.00
# NISP/km2                                 239.00
# Weathering class 0 (%)                     4.30
# Weathering class 0-1 (%)                   0.00
# Weathering class 1 (%)                    27.60
# Weathering class 1-2 (%)                   0.00
# Weathering class 2 (%)                    10.30
# Weathering class 2-3 (%)                   0.00
# Weathering class 3 (%)                    39.70
# Weathering class 3-4 (%)                   8.60
# Weathering class 4 (%)                     7.80
# Weathering class 4-5 (%)                   0.00
# Weathering class 5 (%)                     1.70
# Weathering class 6 (%)                     0.00
# % buried bones                             6.20
# % bones with any carnivore damage         14.70
